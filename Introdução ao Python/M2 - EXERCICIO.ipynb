# %%
filmes = ['Um sonho de liberdade',
          'O Poderoso Chefão',
          'Batman: O Cavaleiro das Trevas',
          'O Poderoso Chefão 2',
          '12 Homens e uma Sentença',
          'A Lista de Schindler',
          'O Senhor dos Aneis: O retorno do Rei',
          'Pulp Fiction: Tempo de Violência',
          'O Senhos dos Aneis: A Sociedade do Anel',
          'Três homens em Conflito']

filmes.pop(0)
filmes
filmes.insert(1, 'Um Sonho de Liberdade')
filmes

# %%
filmes2 = ['Um sonho de liberdade',
          'O Poderoso Chefão',
          'Batman: O Cavaleiro das Trevas',
          'O Poderoso Chefão 2',
          '12 Homens e uma Sentença',
          'A Lista de Schindler',
          'O Senhor dos Aneis: O retorno do Rei',
          'Pulp Fiction: Tempo de Violência',
          'O Senhos dos Aneis: A Sociedade do Anel',
          'Três homens em Conflito',
          'Pulp Fiction: Tempo de Violência',
          'O Senhos dos Aneis: A Sociedade do Anel',
          'Três homens em Conflito']
filmes2
filmes2 = set(filmes2)
filmes2

# %%
filmes3 = {
    'nome':'Um sonho de liberdade',
    'ano':'1994',
    'sinopse':'Dois homens presos se reúnem ao longo de vários anos, encontrando consolo e eventual redenção através de atos de decência comum.'
}
filmes3
filmes3['nome'] = 'O Poderoso Chefão',
filmes3['ano'] = '1972',
filmes3['sinopse'] = 'O patriarca idoso de uma dinastia do crime organizado transfere o controle de seu império clandestino para seu filho relutante.'

filmes3
